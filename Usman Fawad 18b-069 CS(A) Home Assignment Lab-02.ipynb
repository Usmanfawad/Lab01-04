# %% [markdown]
# # HOME TASK 02

# %%
x=  1+2+3+4+5
print(x)
# Out:
# 15

# %%
sara= 23
mark= 19
fatima= 31
avg_age= (sara+mark+fatima)/3
print(avg_age)
# Out:
# 24.333333333333332

# %%
x= 403
y= 73
z= int(x/y)
print("the number of times 73 goes into 403 is " + str(z))
# Out:
# the number of times 73 goes into 403 is 5

# %%
x= 403
y= 73
z= (x/y)
print(z)
# Out:
# 5.52054794520548

# %%
x= (2**10)
print(x)
# Out:
# 1024

# %%
height_sara= 54
height_mark= 57
height_difference= abs(height_sara- height_mark)
print(height_difference)
# Out:
# 3

# %%
>>> min(34.99, 29.95, 31.50)
# Out:
# 29.95

# %%
>>> 2+2 < 4
# Out:
# False

# %%
>>> 7//3 == 1+1
# Out:
# True

# %%
>>> 3**2 + 4**2 == 25
# Out:
# True

# %%
>>> 2+4+6 > 12
# Out:
# False

# %%
>>> 138%19 == 0
# Out:
# False

# %%
>>> min(34.99, 29.95, 31.50) < 30
# Out:
# True

# %%
a= 3
print(a)
# Out:
# 3

# %%
b= 4
print(b)
# Out:
# 4

# %%
c= int(a*a + b*b)
print(c)
# Out:
# 25

# %%
s1= 'ant'
s2= 'bat'
s3= 'cod'

# %%
print(s1+ " " + s2 + " " + s3)
# Out:
# ant bat cod

# %%
print((s1+ " ")*10)
# Out:
# ant ant ant ant ant ant ant ant ant ant

# %%
print(s1+ " " + ((s2+" ")*2) + " " + ((s3+" ")*3))
# Out:
# ant bat bat  cod cod cod

# %%
print((s1 + " " + s2 + " ")*7)
# Out:
# ant bat ant bat ant bat ant bat ant bat ant bat ant bat

# %%
print((s2 + s2 +s3 + " ")*5)
# Out:
# batbatcod batbatcod batbatcod batbatcod batbatcod

# %%
s= '0123456789'

# %%
s[0]
# Out:
# '0'

# %%
s[1]
# Out:
# '1'

# %%
s[6]
# Out:
# '6'

# %%
s[8]
# Out:
# '8'

# %%
s[9]
# Out:
# '9'

# %%
words = ['bat', 'ball', 'barn', 'basket', 'badminton']

# %%
list.sort(words)

# %%
print(words)
# Out:
# ['badminton', 'ball', 'barn', 'basket', 'bat']

# %%
words[0]
# Out:
# 'badminton'

# %%
words[4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-eb349b743174> in <module>()
# ----> 1 words[4]
#
# NameError: name 'words' is not defined

# %%
>>> grades = [9, 7, 7, 10, 3, 9, 6, 6, 2]

# %%
grades.count(7)
# Out:
# 2

# %%
grades[8] = 4

# %%
grades[8]
# Out:
# 4

# %%
max(grades)
# Out:
# 10

# %%
grades.sort()

# %%
print(str(grades))
# Out:
# [3, 4, 6, 6, 7, 7, 9, 9, 10]

# %%
grades_average= (sum(grades) / len(grades))
print(grades_average)
# Out:
# 6.777777777777778

# %%
# Out:
#   File "<ipython-input-11-869119908ad4>", line 1
#     in(22)
#      ^
# SyntaxError: invalid syntax
